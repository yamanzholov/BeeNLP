# %% [markdown]
# I chose 50 tags from the provided Medium dataset and preprocessed the data in the data_manager file.
#
# Then I used TfIDF on the corpus of texts for each tag to extract most relevant keywords for each tag.
#
# I changed the keyword number from 10 to 40 and threshold from 0.1 to 0.9. I used micro averaged f1-score, recall and precision adapted for multi-label classification.

# %%
import pandas as pd

# %%
df
# Out:
#    precision    recall        f1  threshold  keywords_per_tag
# 0   0.097740  0.204341  0.132231        0.1                10
# 1   0.142844  0.130687  0.136495        0.2                10
# 2   0.151355  0.106621  0.125110        0.3                10
# 3   0.149690  0.100391  0.120182        0.4                10
# 4   0.149131  0.099234  0.119170        0.5                10
# 5   0.148647  0.098782  0.118690        0.6                10
# 6   0.148370  0.098541  0.118427        0.7                10
# 7   0.148340  0.098517  0.118401        0.8                10
# 8   0.148337  0.098514  0.118397        0.9                10
# 0   0.094952  0.177772  0.123787        0.1                20
# 1   0.146973  0.108121  0.124588        0.2                20
# 2   0.150271  0.100568  0.120496        0.3                20
# 3   0.149898  0.099731  0.119774        0.4                20
# 4   0.149851  0.099666  0.119712        0.5                20
# ...

# %% [markdown]
# The results can be found in the table below. Overall, we can see that 10 keywords per tag and 0.2 threshold provides the best f1-score.
#
# However, we can see that the results are quite bad. Here are several possible reasons and their solutions.
#
# 1. Simplicity of the algorithm -> we can use more advanced keyword extractor or even a transformer model for multi label classification
# 2. Bug in the code -> There can be a bug in the code that leads to incorrect predictions or metric calculation
# 3. Titles and subtitles are not enough to accurately predict the tags -> Collect not only titles and subtitles, but also the text of the articles, which would help to make more accurate predictions.
